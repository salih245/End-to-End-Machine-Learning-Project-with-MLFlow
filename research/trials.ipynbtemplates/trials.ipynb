# %%
from box import ConfigBox

# %%
d = ConfigBox({"a": 1, "b": {"c": 2, "d": 3}})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 d = ConfigBox({"a": 1, "b": {"c": 2, "d": 3}})
#
# NameError: name 'ConfigBox' is not defined
