# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Salih\\Desktop\\End-to-End-Machine-Learning-Project-with-MLFlow\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Salih\\Desktop\\End-to-End-Machine-Learning-Project-with-MLFlow'

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataTransformationConfig:
    root_dir: Path
    data_path: Path

# %%
from mlProject.constants import *
from mlProject.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath: Path = CONFIG_FILE_PATH,
        params_filepath: Path = PARAMS_FILE_PATH,
        schema_filepath: Path = SCHEMA_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        self.schema = read_yaml(schema_filepath)

        create_directories([self.config.artifacts_root])

    def get_data_transformation_config(self) -> DataTransformationConfig:
        config =self.config.data_transformation

        create_directories([config.root_dir])

        data_transformation_config = DataTransformationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path
        )
        return data_transformation_config

# %%
import os
from mlProject import logger
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
class DataTransformation:
    def __init__(self, config: DataTransformationConfig):
        self.config = config

    def train_test_splitting(self):
        data = pd.read_csv(self.config.data_path)
        train, test = train_test_split(data)

        train.to_csv(os.path.join(self.config.root_dir, "train.csv"), index=False)
        test.to_csv(os.path.join(self.config.root_dir, "test.csv"), index=False)

        logger.info("Splitting is done. Train and test files are saved")
        logger.info(train.shape)
        logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    config_manager = ConfigurationManager()
    data_transformation_config = config_manager.get_data_transformation_config()
    data_transformation = DataTransformation(config=data_transformation_config)
    data_transformation.train_test_splitting()
except Exception as e:
    raise e
# Out:
# [2026-05-15 14:51:25,804]: INFO: common: YAML file 'config\config.yaml' read successfully.]
# [2026-05-15 14:51:25,806]: INFO: common: YAML file 'params.yaml' read successfully.]
# [2026-05-15 14:51:25,809]: INFO: common: YAML file 'schema.yaml' read successfully.]
# [2026-05-15 14:51:25,811]: INFO: common: Directory created: artifacts]
# [2026-05-15 14:51:25,814]: INFO: common: Directory created: artifacts/data_transformation]
# [2026-05-15 14:51:25,847]: INFO: 3967606468: Splitting is done. Train and test files are saved]
# [2026-05-15 14:51:25,848]: INFO: 3967606468: (1199, 12)]
# [2026-05-15 14:51:25,850]: INFO: 3967606468: (400, 12)]
# (1199, 12)
# (400, 12)
